# %%
import pandas as pd

# %%
# reads & stores the train data in a pandas dataframe
df_test = pd.read_csv("/Users/nialdaly/Documents/ey_nextwave/data/data_test.csv", index_col=False)

# prints out the top 5 rows
df_test.head(5)
# Out:
#    Unnamed: 0                                 hash  \
# 0           0  00032f51796fd5437b238e3a9823d13d_31
# 1           1  00032f51796fd5437b238e3a9823d13d_31
# 2           2  00032f51796fd5437b238e3a9823d13d_31
# 3           3  00032f51796fd5437b238e3a9823d13d_31
# 4           4  00032f51796fd5437b238e3a9823d13d_31
#
#                                 trajectory_id time_entry time_exit  vmax  \
# 0  traj_00032f51796fd5437b238e3a9823d13d_31_0   11:43:17  11:50:17   NaN
# 1  traj_00032f51796fd5437b238e3a9823d13d_31_2   12:21:37  12:21:37   0.0
# 2  traj_00032f51796fd5437b238e3a9823d13d_31_3   12:34:27  13:14:11   NaN
# 3  traj_00032f51796fd5437b238e3a9823d13d_31_4   13:25:33  13:43:13   NaN
# 4  traj_00032f51796fd5437b238e3a9823d13d_31_5   15:03:32  15:10:32   NaN
#
#    vmin  vmean       x_entry       y_entry        x_exit        y_exit
# 0   NaN    NaN  3.773413e+06 -1.909828e+07  3.773111e+06 -1.914508e+07
# 1   0.0    0.0  3.773199e+06 -1.914354e+07  3.773199e+06 -1.914354e+07
# ...

# %%
# info on the training data
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202937 entries, 0 to 202936
# Data columns (total 12 columns):
# Unnamed: 0       202937 non-null int64
# hash             202937 non-null object
# trajectory_id    202937 non-null object
# time_entry       202937 non-null object
# time_exit        202937 non-null object
# vmax             54705 non-null float64
# vmin             54705 non-null float64
# vmean            57359 non-null float64
# x_entry          202937 non-null float64
# y_entry          202937 non-null float64
# x_exit           169422 non-null float64
# y_exit           169422 non-null float64
# dtypes: float64(7), int64(1), object(4)
# memory usage: 18.6+ MB

# %%
# describes the training data
df_test.describe()
# Out:
#           Unnamed: 0          vmax          vmin         vmean       x_entry  \
# count  202937.000000  54705.000000  54705.000000  57359.000000  2.029370e+05
# mean   101468.000000      2.821230      2.421897      2.595662  3.760384e+06
# std     58583.010127      7.782798      7.278356      7.332818  8.976732e+03
# min         0.000000     -1.000000     -1.000000     -1.000000  3.741032e+06
# 25%     50734.000000      0.000000      0.000000      0.000000  3.755199e+06
# 50%    101468.000000      0.000000      0.000000      0.000000  3.760110e+06
# 75%    152202.000000      0.570000      0.280000      0.508373  3.767453e+06
# max    202936.000000    153.000000    124.000000    124.000000  3.776975e+06
#
#             y_entry        x_exit        y_exit
# count  2.029370e+05  1.694220e+05  1.694220e+05
# mean  -1.922144e+07  3.760393e+06 -1.922188e+07
# std    7.670937e+04  8.840276e+03  7.487858e+04
# min   -1.937675e+07  3.741020e+06 -1.937675e+07
# ...

# %%
# all records between 3 and 4pm
df_test = df_test[(df_test['time_entry'] >= '15:00:00') & (df_test['time_exit'] <= '16:00:00')]

df_test.head()
# Out:
#     Unnamed: 0                                 hash  \
# 4            4  00032f51796fd5437b238e3a9823d13d_31
# 7            7  000479418b5561ab694a2870cc04fd43_25
# 10          10  000506a39775e5bca661ac80e3f466eb_29
# 13          13   0005401ceddaf27a9b7f0d42ef1fbe95_1
# 23          23   0006535be25bb52dd06983447880c964_5
#
#                                   trajectory_id time_entry time_exit  vmax  \
# 4    traj_00032f51796fd5437b238e3a9823d13d_31_5   15:03:32  15:10:32   NaN
# 7   traj_000479418b5561ab694a2870cc04fd43_25_10   15:29:09  15:30:56   NaN
# 10   traj_000506a39775e5bca661ac80e3f466eb_29_5   15:26:08  15:26:08   NaN
# 13    traj_0005401ceddaf27a9b7f0d42ef1fbe95_1_4   15:35:18  15:42:05   NaN
# 23   traj_0006535be25bb52dd06983447880c964_5_12   15:22:06  15:22:06   NaN
#
#     vmin  vmean       x_entry       y_entry  x_exit  y_exit
# 4    NaN    NaN  3.773118e+06 -1.914490e+07     NaN     NaN
# 7    NaN    NaN  3.769978e+06 -1.934136e+07     NaN     NaN
# ...

# %%
df_test.head()
# Out:
#     Unnamed: 0                                 hash  \
# 4            4  00032f51796fd5437b238e3a9823d13d_31
# 7            7  000479418b5561ab694a2870cc04fd43_25
# 10          10  000506a39775e5bca661ac80e3f466eb_29
# 13          13   0005401ceddaf27a9b7f0d42ef1fbe95_1
# 23          23   0006535be25bb52dd06983447880c964_5
#
#                                   trajectory_id time_entry time_exit  vmax  \
# 4    traj_00032f51796fd5437b238e3a9823d13d_31_5   15:03:32  15:10:32   NaN
# 7   traj_000479418b5561ab694a2870cc04fd43_25_10   15:29:09  15:30:56   NaN
# 10   traj_000506a39775e5bca661ac80e3f466eb_29_5   15:26:08  15:26:08   NaN
# 13    traj_0005401ceddaf27a9b7f0d42ef1fbe95_1_4   15:35:18  15:42:05   NaN
# 23   traj_0006535be25bb52dd06983447880c964_5_12   15:22:06  15:22:06   NaN
#
#     vmin  vmean       x_entry       y_entry  x_exit  y_exit
# 4    NaN    NaN  3.773118e+06 -1.914490e+07     NaN     NaN
# 7    NaN    NaN  3.769978e+06 -1.934136e+07     NaN     NaN
# ...
